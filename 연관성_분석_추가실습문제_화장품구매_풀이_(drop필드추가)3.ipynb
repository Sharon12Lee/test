# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharon12Lee/test/blob/main/%EC%97%B0%EA%B4%80%EC%84%B1_%EB%B6%84%EC%84%9D_%EC%B6%94%EA%B0%80%EC%8B%A4%EC%8A%B5%EB%AC%B8%EC%A0%9C_%ED%99%94%EC%9E%A5%ED%92%88%EA%B5%AC%EB%A7%A4_%ED%92%80%EC%9D%B4_(drop%ED%95%84%EB%93%9C%EC%B6%94%EA%B0%80)3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# \# Association Rules 추가 실습

# %%
import pandas as pd
#import numpy as np
#from scipy.spatial.distance import cosine
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# # Cosmetics Purchases 아이템 간 연관성 분석

# %%
cosmetics_df = pd.read_csv('Cosmetics.csv')
cosmetics_df.set_index('Trans. ',inplace=True)
cosmetics_df.head()
#cosmetics_df
# Out:
#          Bag  Blush  Nail Polish  Brushes  Concealer  Eyebrow Pencils  \
# Trans.
# 1          0      1            1        1          1                0
# 2          0      0            1        0          1                0
# 3          0      1            0        0          1                1
# 4          0      0            1        1          1                0
# 5          0      1            0        0          1                0
#
#          Bronzer  Lip liner  Mascara  Eye shadow  Foundation  Lip Gloss  \
# Trans.
# 1              1          1        1           0           0          0
# 2              1          1        0           0           1          1
# 3              1          1        1           1           1          1
# 4              1          0        0           0           1          0
# 5              1          1        1           1           0          1
#
#          Lipstick  Eyeliner
# Trans.
# 1               0         1
# ...

# %%
frequentItemsets = apriori(cosmetics_df, min_support=0.1, use_colnames=True)
rules = association_rules(frequentItemsets)
results = rules.sort_values(by=['lift'], ascending=False)
results.drop(columns=['antecedent support', 'consequent support', 'conviction', 'zhangs_metric', 'representativity', 'jaccard', 'certainty', 'kulczynski'])
# Out:
# /usr/local/lib/python3.11/dist-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                           antecedents    consequents  support  confidence  \
# 0                           (Brushes)  (Nail Polish)    0.149    1.000000
# 21     (Eye shadow, Concealer, Blush)      (Mascara)    0.119    0.959677
# 4                 (Eye shadow, Blush)      (Mascara)    0.169    0.928571
# 6           (Eye shadow, Nail Polish)      (Mascara)    0.119    0.908397
# 11            (Eye shadow, Concealer)      (Mascara)    0.179    0.890547
# 13              (Eye shadow, Bronzer)      (Mascara)    0.124    0.879433
# 23  (Eye shadow, Eyeliner, Concealer)      (Mascara)    0.114    0.876923
# 5                    (Mascara, Blush)   (Eye shadow)    0.169    0.918478
# ...

# %% [markdown]
# ### Interpret the first three rules in the output in words.

# %%
results.head(3).drop(columns=['antecedent support', 'consequent support', 'conviction', 'zhangs_metric'])
# Out:
#                        antecedents    consequents  support  confidence  \
# 0                        (Brushes)  (Nail Polish)    0.149    1.000000
# 21  (Eye shadow, Concealer, Blush)      (Mascara)    0.119    0.959677
# 4              (Eye shadow, Blush)      (Mascara)    0.169    0.928571
#
#         lift  representativity  leverage   jaccard  certainty  kulczynski
# 0   3.571429               1.0  0.107280  0.532143   1.000000    0.766071
# 21  2.688172               1.0  0.074732  0.328729   0.937290    0.646505
# 4   2.601040               1.0  0.104026  0.456757   0.888914    0.700980
